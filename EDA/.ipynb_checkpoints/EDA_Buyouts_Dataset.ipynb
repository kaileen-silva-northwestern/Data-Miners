# %%
import pandas as pd
import numpy as np
import re
import seaborn as sns

# %%
buyouts = pd.read_csv('buyout_agreements.csv')

# %%
buyouts.shape
# Out:
# (5820, 27)

# %%
# what are its columns
buyouts.columns
# Out:
# Index(['Case Number', 'Pre Buyout Disclosure Declaration Date',
#        'Buyout Agreement Date', 'Buyout Amount', 'Unknown Amount',
#        'Other Consideration', 'Number of Tenants', 'Address', 'ZIP Code',
#        'Supervisor District', 'Analysis Neighborhood', 'point',
#        'geocoding_confidence', 'SF Find Neighborhoods',
#        'Current Police Districts', 'Current Supervisor Districts',
#        'Analysis Neighborhoods', 'DELETE - Neighborhoods',
#        'DELETE - Police Districts', 'DELETE - Supervisor Districts',
#        'DELETE - Fire Prevention Districts', 'DELETE - Zip Codes',
#        'Areas of Vulnerability, 2016', 'Central Market/Tenderloin Boundary',
#        'Invest In Neighborhoods (IIN) Areas',
#        'Civic Center Harm Reduction Project Boundary', 'Neighborhoods'],
#       dtype='object')

# %%
# # col_to_drop = ['id','brewery_id','Standard Reference Method','Universal Product Code',
# #             'filepath', 'Description', 'add_user','last_mod', 'Website']

# # beers2 = beers.drop(columns=col_to_drop, inplace=False)
# beers2.info()

# %%
buyouts.head()
# Out:
#   Case Number Pre Buyout Disclosure Declaration Date Buyout Agreement Date  \
# 0     B153174                             11/16/2015            03/28/2016
# 1     B171997                             08/04/2017                   NaN
# 2     B153129                             11/12/2015            02/19/2016
# 3     B161104                             03/21/2016                   NaN
# 4     B172057                             08/09/2017            08/24/2018
#
#    Buyout Amount Unknown Amount Other Consideration  Number of Tenants  \
# 0        55000.0            NaN                 NaN                2.0
# 1            NaN            NaN                 NaN                NaN
# 2        35000.0            NaN                 NaN                1.0
# 3            NaN            NaN                 NaN                NaN
# 4        15000.0            NaN                 NaN                1.0
#
#                              Address  ZIP Code  Supervisor District  ...  \
# ...

# %%
buyouts.describe()
# Out:
#        Buyout Amount  Number of Tenants      ZIP Code  Supervisor District  \
# count    2343.000000        2389.000000   5818.000000          5818.000000
# mean    44334.225732           1.876517  94116.159161             5.818322
# std     41491.836714           1.135791      7.977735             3.119503
# min         0.000000           1.000000  94102.000000             1.000000
# 25%     18000.000000           1.000000  94110.000000             3.000000
# 50%     32310.000000           2.000000  94115.000000             5.000000
# 75%     58025.000000           2.000000  94121.000000             9.000000
# max    469562.500000          13.000000  94158.000000            11.000000
#
#        geocoding_confidence  SF Find Neighborhoods  Current Police Districts  \
# count           5818.000000            5815.000000               5818.000000
# mean              99.917356              56.330353                  6.102269
# ...

# %%
buyouts.describe(include=['O'])
# Out:
#        Case Number Pre Buyout Disclosure Declaration Date  \
# count         5820                                   5563
# unique        5820                                   1593
# top        B153174                             07/19/2018
# freq             1                                     48
#
#        Buyout Agreement Date Unknown Amount Other Consideration  \
# count                   2380             38                 633
# unique                  1228              1                   1
# top               07/10/2018           True                True
# freq                      15             38                 633
#
#                  Address Analysis Neighborhood  \
# count               5820                  5818
# unique              4539                    39
# top     120 Ellis Street               Mission
# freq                  30                   709
#
#                                                 point
# ...

# %%
buyouts.boxplot(column='Buyout Amount')
# Out:
# <AxesSubplot:>

# %%
buyouts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5820 entries, 0 to 5819
# Data columns (total 27 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Case Number                                   5820 non-null   object
#  1   Pre Buyout Disclosure Declaration Date        5563 non-null   object
#  2   Buyout Agreement Date                         2380 non-null   object
#  3   Buyout Amount                                 2343 non-null   float64
#  4   Unknown Amount                                38 non-null     object
#  5   Other Consideration                           633 non-null    object
#  6   Number of Tenants                             2389 non-null   float64
#  7   Address                                       5820 non-null   object
#  8   ZIP Code                                      5818 non-null   float64
# ...

# %%
buyouts.isnull().head()
# Out:
#    Case Number  Pre Buyout Disclosure Declaration Date  Buyout Agreement Date  \
# 0        False                                   False                  False
# 1        False                                   False                   True
# 2        False                                   False                  False
# 3        False                                   False                   True
# 4        False                                   False                  False
#
#    Buyout Amount  Unknown Amount  Other Consideration  Number of Tenants  \
# 0          False            True                 True              False
# 1           True            True                 True               True
# 2          False            True                 True              False
# 3           True            True                 True               True
# 4          False            True                 True              False
#
# ...

# %%
buyouts.isnull().sum()
# Out:
# Case Number                                        0
# Pre Buyout Disclosure Declaration Date           257
# Buyout Agreement Date                           3440
# Buyout Amount                                   3477
# Unknown Amount                                  5782
# Other Consideration                             5187
# Number of Tenants                               3431
# Address                                            0
# ZIP Code                                           2
# Supervisor District                                2
# Analysis Neighborhood                              2
# point                                              2
# geocoding_confidence                               2
# SF Find Neighborhoods                              5
# Current Police Districts                           2
# Current Supervisor Districts                       2
# Analysis Neighborhoods                             2
# DELETE - Neighborhoods                             2
# ...

# %%
buyouts.Address.unique().shape
# Out:
# (4539,)

# %%
# beers.City.isnull().sum()

# df = beers[beers.City.isnull()]
# df.shape

# %%
col_to_drop = ['DELETE - Neighborhoods','DELETE - Supervisor Districts','DELETE - Fire Prevention Districts',
               'DELETE - Zip Codes', 'DELETE - Police Districts']
buyouts2 = buyouts.drop(columns =col_to_drop, inplace=False)

# %%
buyouts2
# Out:
#      Case Number Pre Buyout Disclosure Declaration Date Buyout Agreement Date  \
# 0        B153174                             11/16/2015            03/28/2016
# 1        B171997                             08/04/2017                   NaN
# 2        B153129                             11/12/2015            02/19/2016
# 3        B161104                             03/21/2016                   NaN
# 4        B172057                             08/09/2017            08/24/2018
# ...          ...                                    ...                   ...
# 5815     B171010                             04/14/2017                   NaN
# 5816     B190588                             03/25/2019                   NaN
# 5817     B201248                             09/03/2020                   NaN
# 5818     B161301                             04/07/2016                   NaN
# 5819     B181121                             04/05/2018                   NaN
#
# ...

# %%
buyouts3 = buyouts2.dropna(subset=['Pre Buyout Disclosure Declaration Date'])
buyouts3
# Out:
#      Case Number Pre Buyout Disclosure Declaration Date Buyout Agreement Date  \
# 0        B153174                             11/16/2015            03/28/2016
# 1        B171997                             08/04/2017                   NaN
# 2        B153129                             11/12/2015            02/19/2016
# 3        B161104                             03/21/2016                   NaN
# 4        B172057                             08/09/2017            08/24/2018
# ...          ...                                    ...                   ...
# 5815     B171010                             04/14/2017                   NaN
# 5816     B190588                             03/25/2019                   NaN
# 5817     B201248                             09/03/2020                   NaN
# 5818     B161301                             04/07/2016                   NaN
# 5819     B181121                             04/05/2018                   NaN
#
# ...

# %%
buyouts4 = buyouts3.dropna(subset=['Buyout Agreement Date'])

# %%
buyouts4
# Out:
#      Case Number Pre Buyout Disclosure Declaration Date Buyout Agreement Date  \
# 0        B153174                             11/16/2015            03/28/2016
# 2        B153129                             11/12/2015            02/19/2016
# 4        B172057                             08/09/2017            08/24/2018
# 7        B220017                             01/12/2022            02/18/2022
# 8        B172093                             08/16/2017            10/30/2017
# ...          ...                                    ...                   ...
# 5794     B192837                             10/10/2019            01/22/2020
# 5798     B201848                             12/29/2021            03/18/2021
# 5803     B181876                             06/21/2018            12/03/2018
# 5807     B200645                             05/07/2020            09/08/2020
# 5811     B180500                             02/14/2018            06/21/2018
#
# ...

# %%
buyouts5 = buyouts4.dropna(subset=['Buyout Amount'])

# %%
buyouts5
# Out:
#      Case Number Pre Buyout Disclosure Declaration Date Buyout Agreement Date  \
# 0        B153174                             11/16/2015            03/28/2016
# 2        B153129                             11/12/2015            02/19/2016
# 4        B172057                             08/09/2017            08/24/2018
# 7        B220017                             01/12/2022            02/18/2022
# 8        B172093                             08/16/2017            10/30/2017
# ...          ...                                    ...                   ...
# 5794     B192837                             10/10/2019            01/22/2020
# 5798     B201848                             12/29/2021            03/18/2021
# 5803     B181876                             06/21/2018            12/03/2018
# 5807     B200645                             05/07/2020            09/08/2020
# 5811     B180500                             02/14/2018            06/21/2018
#
# ...

# %%
buyouts5.rename(columns={"Unknown Amount": "unknown_amount"})
# Out:
#      Case Number Pre Buyout Disclosure Declaration Date Buyout Agreement Date  \
# 0        B153174                             11/16/2015            03/28/2016
# 2        B153129                             11/12/2015            02/19/2016
# 4        B172057                             08/09/2017            08/24/2018
# 7        B220017                             01/12/2022            02/18/2022
# 8        B172093                             08/16/2017            10/30/2017
# ...          ...                                    ...                   ...
# 5794     B192837                             10/10/2019            01/22/2020
# 5798     B201848                             12/29/2021            03/18/2021
# 5803     B181876                             06/21/2018            12/03/2018
# 5807     B200645                             05/07/2020            09/08/2020
# 5811     B180500                             02/14/2018            06/21/2018
#
# ...

# %%
# TODO: use Boolean filtering to select rows where beer_abv values are missing and assign this to missing_abv
missing_buyout_amt = buyouts5[buyouts5.isnull()]
#missing_abv stored the command to locate the row(s) with missing information

# TODO: use the nunique() method to determine the number of different beers with missing_abv values
# missing_buyout.beer_name.nunique()

# %%
missing_buyout_amt
# Out:
#      Case Number Pre Buyout Disclosure Declaration Date Buyout Agreement Date  \
# 0            NaN                                    NaN                   NaN
# 2            NaN                                    NaN                   NaN
# 4            NaN                                    NaN                   NaN
# 7            NaN                                    NaN                   NaN
# 8            NaN                                    NaN                   NaN
# ...          ...                                    ...                   ...
# 5794         NaN                                    NaN                   NaN
# 5798         NaN                                    NaN                   NaN
# 5803         NaN                                    NaN                   NaN
# 5807         NaN                                    NaN                   NaN
# 5811         NaN                                    NaN                   NaN
#
# ...

# %%
buyouts6 = buyouts5.dropna(subset=['Other Consideration'])

# %%
buyouts6
# Out:
#      Case Number Pre Buyout Disclosure Declaration Date Buyout Agreement Date  \
# 16       B181311                             04/25/2018            06/22/2018
# 19       B192941                             10/16/2019            12/23/2019
# 30       B162790                             09/01/2016            11/07/2016
# 32       B171756                             07/07/2017            11/02/2017
# 38       B191312                             06/14/2019            08/15/2019
# ...          ...                                    ...                   ...
# 5758     B153302                             11/25/2015            09/29/2016
# 5786     B152900                             10/21/2015            09/19/2019
# 5788     B163456                             11/01/2016            12/22/2016
# 5798     B201848                             12/29/2021            03/18/2021
# 5803     B181876                             06/21/2018            12/03/2018
#
# ...

# %%
buyouts7 = buyouts6.dropna(subset=['Number of Tenants'])

# %%
buyouts7
# Out:
#      Case Number Pre Buyout Disclosure Declaration Date Buyout Agreement Date  \
# 16       B181311                             04/25/2018            06/22/2018
# 19       B192941                             10/16/2019            12/23/2019
# 30       B162790                             09/01/2016            11/07/2016
# 32       B171756                             07/07/2017            11/02/2017
# 38       B191312                             06/14/2019            08/15/2019
# ...          ...                                    ...                   ...
# 5758     B153302                             11/25/2015            09/29/2016
# 5786     B152900                             10/21/2015            09/19/2019
# 5788     B163456                             11/01/2016            12/22/2016
# 5798     B201848                             12/29/2021            03/18/2021
# 5803     B181876                             06/21/2018            12/03/2018
#
# ...

# %%
buyouts8 = buyouts7.dropna(subset=['ZIP Code'])

# %%
buyouts8
# Out:
#      Case Number Pre Buyout Disclosure Declaration Date Buyout Agreement Date  \
# 16       B181311                             04/25/2018            06/22/2018
# 19       B192941                             10/16/2019            12/23/2019
# 30       B162790                             09/01/2016            11/07/2016
# 32       B171756                             07/07/2017            11/02/2017
# 38       B191312                             06/14/2019            08/15/2019
# ...          ...                                    ...                   ...
# 5758     B153302                             11/25/2015            09/29/2016
# 5786     B152900                             10/21/2015            09/19/2019
# 5788     B163456                             11/01/2016            12/22/2016
# 5798     B201848                             12/29/2021            03/18/2021
# 5803     B181876                             06/21/2018            12/03/2018
#
# ...

# %%
buyouts9 = buyouts8.dropna(subset=['Supervisor District'])

# %%
buyouts9
# Out:
#      Case Number Pre Buyout Disclosure Declaration Date Buyout Agreement Date  \
# 16       B181311                             04/25/2018            06/22/2018
# 19       B192941                             10/16/2019            12/23/2019
# 30       B162790                             09/01/2016            11/07/2016
# 32       B171756                             07/07/2017            11/02/2017
# 38       B191312                             06/14/2019            08/15/2019
# ...          ...                                    ...                   ...
# 5758     B153302                             11/25/2015            09/29/2016
# 5786     B152900                             10/21/2015            09/19/2019
# 5788     B163456                             11/01/2016            12/22/2016
# 5798     B201848                             12/29/2021            03/18/2021
# 5803     B181876                             06/21/2018            12/03/2018
#
# ...

# %%
buyouts10 = buyouts9.dropna(subset=['Analysis Neighborhood'])

# %%
buyouts10
# Out:
#      Case Number Pre Buyout Disclosure Declaration Date Buyout Agreement Date  \
# 16       B181311                             04/25/2018            06/22/2018
# 19       B192941                             10/16/2019            12/23/2019
# 30       B162790                             09/01/2016            11/07/2016
# 32       B171756                             07/07/2017            11/02/2017
# 38       B191312                             06/14/2019            08/15/2019
# ...          ...                                    ...                   ...
# 5758     B153302                             11/25/2015            09/29/2016
# 5786     B152900                             10/21/2015            09/19/2019
# 5788     B163456                             11/01/2016            12/22/2016
# 5798     B201848                             12/29/2021            03/18/2021
# 5803     B181876                             06/21/2018            12/03/2018
#
# ...

# %%
buyouts11 = buyouts10.dropna(subset=['point'])

# %%
buyouts11
# Out:
#      Case Number Pre Buyout Disclosure Declaration Date Buyout Agreement Date  \
# 16       B181311                             04/25/2018            06/22/2018
# 19       B192941                             10/16/2019            12/23/2019
# 30       B162790                             09/01/2016            11/07/2016
# 32       B171756                             07/07/2017            11/02/2017
# 38       B191312                             06/14/2019            08/15/2019
# ...          ...                                    ...                   ...
# 5758     B153302                             11/25/2015            09/29/2016
# 5786     B152900                             10/21/2015            09/19/2019
# 5788     B163456                             11/01/2016            12/22/2016
# 5798     B201848                             12/29/2021            03/18/2021
# 5803     B181876                             06/21/2018            12/03/2018
#
# ...

# %%
buyouts12 = buyouts11.dropna(subset=['geocoding_confidence'])

# %%
buyouts12
# Out:
#      Case Number Pre Buyout Disclosure Declaration Date Buyout Agreement Date  \
# 16       B181311                             04/25/2018            06/22/2018
# 19       B192941                             10/16/2019            12/23/2019
# 30       B162790                             09/01/2016            11/07/2016
# 32       B171756                             07/07/2017            11/02/2017
# 38       B191312                             06/14/2019            08/15/2019
# ...          ...                                    ...                   ...
# 5758     B153302                             11/25/2015            09/29/2016
# 5786     B152900                             10/21/2015            09/19/2019
# 5788     B163456                             11/01/2016            12/22/2016
# 5798     B201848                             12/29/2021            03/18/2021
# 5803     B181876                             06/21/2018            12/03/2018
#
# ...

# %%
buyouts13 = buyouts12.dropna(subset=['SF Find Neighborhoods'])

# %%
buyouts13
# Out:
#      Case Number Pre Buyout Disclosure Declaration Date Buyout Agreement Date  \
# 16       B181311                             04/25/2018            06/22/2018
# 19       B192941                             10/16/2019            12/23/2019
# 30       B162790                             09/01/2016            11/07/2016
# 32       B171756                             07/07/2017            11/02/2017
# 38       B191312                             06/14/2019            08/15/2019
# ...          ...                                    ...                   ...
# 5758     B153302                             11/25/2015            09/29/2016
# 5786     B152900                             10/21/2015            09/19/2019
# 5788     B163456                             11/01/2016            12/22/2016
# 5798     B201848                             12/29/2021            03/18/2021
# 5803     B181876                             06/21/2018            12/03/2018
#
# ...

# %%
buyouts14 = buyouts13.dropna(subset=['Current Police Districts'])

# %%
buyouts14
# Out:
#      Case Number Pre Buyout Disclosure Declaration Date Buyout Agreement Date  \
# 16       B181311                             04/25/2018            06/22/2018
# 19       B192941                             10/16/2019            12/23/2019
# 30       B162790                             09/01/2016            11/07/2016
# 32       B171756                             07/07/2017            11/02/2017
# 38       B191312                             06/14/2019            08/15/2019
# ...          ...                                    ...                   ...
# 5758     B153302                             11/25/2015            09/29/2016
# 5786     B152900                             10/21/2015            09/19/2019
# 5788     B163456                             11/01/2016            12/22/2016
# 5798     B201848                             12/29/2021            03/18/2021
# 5803     B181876                             06/21/2018            12/03/2018
#
# ...

# %%
buyouts15 = buyouts14.dropna(subset=['Current Supervisor Districts'])

# %%
buyouts15
# Out:
#      Case Number Pre Buyout Disclosure Declaration Date Buyout Agreement Date  \
# 16       B181311                             04/25/2018            06/22/2018
# 19       B192941                             10/16/2019            12/23/2019
# 30       B162790                             09/01/2016            11/07/2016
# 32       B171756                             07/07/2017            11/02/2017
# 38       B191312                             06/14/2019            08/15/2019
# ...          ...                                    ...                   ...
# 5758     B153302                             11/25/2015            09/29/2016
# 5786     B152900                             10/21/2015            09/19/2019
# 5788     B163456                             11/01/2016            12/22/2016
# 5798     B201848                             12/29/2021            03/18/2021
# 5803     B181876                             06/21/2018            12/03/2018
#
# ...

# %%
buyouts15 = buyouts14.dropna(subset=['Analysis Neighborhood'])

# %%
buyouts15
# Out:
#      Case Number Pre Buyout Disclosure Declaration Date Buyout Agreement Date  \
# 16       B181311                             04/25/2018            06/22/2018
# 19       B192941                             10/16/2019            12/23/2019
# 30       B162790                             09/01/2016            11/07/2016
# 32       B171756                             07/07/2017            11/02/2017
# 38       B191312                             06/14/2019            08/15/2019
# ...          ...                                    ...                   ...
# 5758     B153302                             11/25/2015            09/29/2016
# 5786     B152900                             10/21/2015            09/19/2019
# 5788     B163456                             11/01/2016            12/22/2016
# 5798     B201848                             12/29/2021            03/18/2021
# 5803     B181876                             06/21/2018            12/03/2018
#
# ...

# %%
buyouts16 = buyouts15.dropna(subset=['Areas of Vulnerability, 2016'])

# %%
buyouts16['Unknown Amount']= buyouts16['Unknown Amount'].fillna(0)

# %%
#buyouts17 = buyouts16.dropna(subset=['Civic Center Harm Reduction Project Boundary'])

# %%
buyouts16['Central Market/Tenderloin Boundary']= buyouts16['Central Market/Tenderloin Boundary'].fillna(0)

# %%
buyouts16['Areas of Vulnerability, 2016']= buyouts16['Areas of Vulnerability, 2016'].fillna(0)

# %%
buyouts16['Invest In Neighborhoods (IIN) Areas']= buyouts16['Invest In Neighborhoods (IIN) Areas'].fillna(0)

# %%
buyouts16['Civic Center Harm Reduction Project Boundary']= buyouts16['Civic Center Harm Reduction Project Boundary'].fillna(0)

# %%
buyouts16
# Out:
#      Case Number Pre Buyout Disclosure Declaration Date Buyout Agreement Date  \
# 16       B181311                             04/25/2018            06/22/2018
# 19       B192941                             10/16/2019            12/23/2019
# 30       B162790                             09/01/2016            11/07/2016
# 32       B171756                             07/07/2017            11/02/2017
# 38       B191312                             06/14/2019            08/15/2019
# ...          ...                                    ...                   ...
# 5758     B153302                             11/25/2015            09/29/2016
# 5786     B152900                             10/21/2015            09/19/2019
# 5788     B163456                             11/01/2016            12/22/2016
# 5798     B201848                             12/29/2021            03/18/2021
# 5803     B181876                             06/21/2018            12/03/2018
#
# ...

# %%
#Unknown Amount
#Central Market/Tenderloin Boundary
#Invest In Neighborhoods (IIN) Areas
#Civic Center Harm Reduction Project Boundary

# %%
buyouts16.isnull()
# Out:
#       Case Number  Pre Buyout Disclosure Declaration Date  \
# 16          False                                   False
# 19          False                                   False
# 30          False                                   False
# 32          False                                   False
# 38          False                                   False
# ...           ...                                     ...
# 5758        False                                   False
# 5786        False                                   False
# 5788        False                                   False
# 5798        False                                   False
# 5803        False                                   False
#
#       Buyout Agreement Date  Buyout Amount  Unknown Amount  \
# 16                    False          False           False
# 19                    False          False           False
# 30                    False          False           False
# ...

# %%
buyouts_eda = buyouts16

# %%
buyouts_eda
# Out:
#      Case Number Pre Buyout Disclosure Declaration Date Buyout Agreement Date  \
# 16       B181311                             04/25/2018            06/22/2018
# 19       B192941                             10/16/2019            12/23/2019
# 30       B162790                             09/01/2016            11/07/2016
# 32       B171756                             07/07/2017            11/02/2017
# 38       B191312                             06/14/2019            08/15/2019
# ...          ...                                    ...                   ...
# 5758     B153302                             11/25/2015            09/29/2016
# 5786     B152900                             10/21/2015            09/19/2019
# 5788     B163456                             11/01/2016            12/22/2016
# 5798     B201848                             12/29/2021            03/18/2021
# 5803     B181876                             06/21/2018            12/03/2018
#
# ...

# %%
#buyouts16.to_csv('buyouts_eda.csv')

# %%
#ETL Pipeline_
buyouts17 = buyouts16.rename(columns={"Pre Buyout Disclosure Declaration Date": "Pre_Buyout_Disclosure_Declaration_Date"})

# %%
buyouts17["Pre_Buyout_Disclosure_Declaration_Date"]
# Out:
# 16      04/25/2018
# 19      10/16/2019
# 30      09/01/2016
# 32      07/07/2017
# 38      06/14/2019
#            ...
# 5758    11/25/2015
# 5786    10/21/2015
# 5788    11/01/2016
# 5798    12/29/2021
# 5803    06/21/2018
# Name: Pre_Buyout_Disclosure_Declaration_Date, Length: 557, dtype: object

# %%
buyouts17["Pre_Buyout_Disclosure_Declaration_Date"] = pd.to_datetime(buyouts17["Pre_Buyout_Disclosure_Declaration_Date"])

# %%
buyouts17.Pre_Buyout_Disclosure_Declaration_Date.apply(lambda x: x.strftime('%m%d%Y')).astype(str)
# Out:
# 16      04252018
# 19      10162019
# 30      09012016
# 32      07072017
# 38      06142019
#           ...
# 5758    11252015
# 5786    10212015
# 5788    11012016
# 5798    12292021
# 5803    06212018
# Name: Pre_Buyout_Disclosure_Declaration_Date, Length: 557, dtype: object

# %%
buyouts18 = buyouts17.rename(columns={"Buyout Agreement Date": "Buyout_Agreement_Date"})

# %%
buyouts18["Buyout_Agreement_Date"] = pd.to_datetime(buyouts18["Buyout_Agreement_Date"])

# %%
buyouts18.Pre_Buyout_Disclosure_Declaration_Date.apply(lambda x: x.strftime('%m%d%Y')).astype(str)
# Out:
# 16      04252018
# 19      10162019
# 30      09012016
# 32      07072017
# 38      06142019
#           ...
# 5758    11252015
# 5786    10212015
# 5788    11012016
# 5798    12292021
# 5803    06212018
# Name: Pre_Buyout_Disclosure_Declaration_Date, Length: 557, dtype: object

# %%
buyouts18.to_csv('buyouts_eda.csv')

# %%
buyouts18
# Out:
#      Case Number Pre_Buyout_Disclosure_Declaration_Date Buyout_Agreement_Date  \
# 16       B181311                             2018-04-25            2018-06-22
# 19       B192941                             2019-10-16            2019-12-23
# 30       B162790                             2016-09-01            2016-11-07
# 32       B171756                             2017-07-07            2017-11-02
# 38       B191312                             2019-06-14            2019-08-15
# ...          ...                                    ...                   ...
# 5758     B153302                             2015-11-25            2016-09-29
# 5786     B152900                             2015-10-21            2019-09-19
# 5788     B163456                             2016-11-01            2016-12-22
# 5798     B201848                             2021-12-29            2021-03-18
# 5803     B181876                             2018-06-21            2018-12-03
#
# ...
