# %%
import pandas as pd
import sqlalchemy as sa
from sqlalchemy import Table, MetaData, Column, Integer
import os

# %%
username = os.getenv('AZURE_MSDS432_USERNAME')
password = os.getenv('AZURE_MSDS432_PASSWORD')
host = 'mysqlserver-432.database.windows.net'
database = 'mySampleDatabase'
authentication = "SqlPassword"
conn_string = sa.engine.url.URL(
     "mssql+pyodbc",
     username=username,
     password=password,
     host=host,
     port=1433,
     database=database,
     query={"driver": "ODBC Driver 18 for SQL Server", "authentication": authentication}
 )

# %%
engine = sa.create_engine(conn_string, pool_timeout=60)
connection = engine.connect()

# %%
query = """
select schema_name(t.schema_id) as schema_name,
       t.name as table_name,
       t.create_date,
       t.modify_date
from sys.tables t
order by schema_name,
         table_name;
"""

tables = pd.read_sql_query(query, connection)
tables
# Out:
#    schema_name                             table_name             create_date  \
# 0          dbo                           BuildVersion 2022-05-15 20:04:00.113
# 1          dbo                               ErrorLog 2022-05-15 20:04:00.113
# 2          dbo                           Rel_Building 2022-05-17 22:49:05.513
# 3          dbo                   Rel_BuyoutAgreements 2022-05-17 22:47:28.627
# 4          dbo                       Rel_Demographics 2022-05-17 22:34:37.987
# 5          dbo                   Rel_Eviction_Notices 2022-05-17 21:59:47.223
# 6          dbo                           Rel_Location 2022-05-17 22:25:35.210
# 7          dbo            SF_Addresses_With_Units_Raw 2022-05-19 01:46:22.717
# 8          dbo               SF_Buyout_Agreements_Raw 2022-05-16 00:27:00.917
# 9          dbo                SF_Eviction_Notices_Raw 2022-05-16 00:41:20.143
# 10         dbo               Zip_Atlas_Median_Age_Raw 2022-05-16 00:26:38.500
# 11         dbo  Zip_Atlas_Median_Household_Income_Raw 2022-05-16 00:26:44.743
# 12         dbo       Zip_Atlas_Population_Density_Raw 2022-05-16 00:26:41.683
#
#                modify_date
# 0  2022-05-15 20:04:01.767
# 1  2022-05-15 20:04:01.767
# 2  2022-05-19 22:05:23.507
# 3  2022-05-19 22:05:23.503
# 4  2022-05-19 22:21:30.853
# 5  2022-05-19 23:24:13.557
# 6  2022-05-25 12:56:24.520
# 7  2022-05-19 01:46:22.793
# 8  2022-05-16 00:27:00.943
# 9  2022-05-16 00:41:20.190
# 10 2022-05-16 00:26:38.530
# 11 2022-05-16 00:26:44.773
# 12 2022-05-16 00:26:41.693

# %% [markdown]
# ### DIM_Eviction_Reason Table

# %%
## Drop the table
engine = sa.create_engine(conn_string, pool_timeout=60)
connection = engine.connect()

engine.execute("DROP TABLE dbo.FACT_SanFrancisco;")

# %%
create_DIM_Eviction_Reason_table_query = """
CREATE TABLE DIM_Eviction_Reason
(
    Non_Payment                                          BIT,
    Breach                                               BIT,
    Nuisance                                             BIT,
    Illegal_Use                                          BIT,
    Failure_to_Sign_Renewal                              BIT,
    Access_Denial                                        BIT,
    Unapproved_Subtenant                                 BIT,
    Owner_Move_In                                        BIT,
    Demolition                                           BIT,
    Capital_Improvement                                  BIT,
    Substantial_Rehab                                    BIT,
    Ellis_Act_WithDrawal                                 BIT,
    Condo_Conversion                                     BIT,
    Roommate_Same_Unit                                   BIT,
    Other_Cause                                          BIT,
    Late_Payments                                        BIT,
    Lead_Remediation                                     BIT,
    Development                                          BIT,
    Good_Samaritan_Ends                                  BIT,
    Reason_Key                                           VARCHAR(432) PRIMARY KEY
)
"""

# %%
## Create the table
engine = sa.create_engine(conn_string, pool_timeout=60)
connection = engine.connect()

engine.execute(create_DIM_Eviction_Reason_table_query)

# %%
tables = pd.read_sql_query(query, connection)
tables
# Out:
#    schema_name                             table_name             create_date  \
# 0          dbo                           BuildVersion 2022-05-15 20:04:00.113
# 1          dbo                    DIM_Eviction_Reason 2022-05-26 01:34:00.140
# 2          dbo                               ErrorLog 2022-05-15 20:04:00.113
# 3          dbo                      FACT_SanFrancisco 2022-05-25 23:57:41.150
# 4          dbo                           Rel_Building 2022-05-17 22:49:05.513
# 5          dbo                   Rel_BuyoutAgreements 2022-05-17 22:47:28.627
# 6          dbo                       Rel_Demographics 2022-05-17 22:34:37.987
# 7          dbo                   Rel_Eviction_Notices 2022-05-17 21:59:47.223
# 8          dbo                           Rel_Location 2022-05-17 22:25:35.210
# 9          dbo            SF_Addresses_With_Units_Raw 2022-05-19 01:46:22.717
# 10         dbo               SF_Buyout_Agreements_Raw 2022-05-16 00:27:00.917
# 11         dbo                SF_Eviction_Notices_Raw 2022-05-16 00:41:20.143
# 12         dbo               Zip_Atlas_Median_Age_Raw 2022-05-16 00:26:38.500
# 13         dbo  Zip_Atlas_Median_Household_Income_Raw 2022-05-16 00:26:44.743
# 14         dbo       Zip_Atlas_Population_Density_Raw 2022-05-16 00:26:41.683
#
#                modify_date
# 0  2022-05-15 20:04:01.767
# 1  2022-05-26 01:34:00.140
# 2  2022-05-15 20:04:01.767
# 3  2022-05-25 23:57:41.150
# 4  2022-05-19 22:05:23.507
# 5  2022-05-26 00:44:10.810
# 6  2022-05-19 22:21:30.853
# 7  2022-05-19 23:24:13.557
# 8  2022-05-25 12:56:24.520
# 9  2022-05-19 01:46:22.793
# 10 2022-05-16 00:27:00.943
# 11 2022-05-16 00:41:20.190
# 12 2022-05-16 00:26:38.530
# 13 2022-05-16 00:26:44.773
# 14 2022-05-16 00:26:41.693

# %% [markdown]
# ### BR_Reason Table

# %%
create_BR_Reason_table_query = """
CREATE TABLE BR_Reason
(
    Reason_GroupKey                                     VARCHAR(432) PRIMARY KEY,
    Reason_Key                                          VARCHAR(432) FOREIGN KEY REFERENCES DIM_Eviction_Reason(Reason_Key)
)
"""

# %%
## Create the table
engine = sa.create_engine(conn_string, pool_timeout=60)
connection = engine.connect()

engine.execute(create_BR_Reason_table_query)

# %%
tables = pd.read_sql_query(query, connection)
tables
# Out:
#    schema_name                             table_name             create_date  \
# 0          dbo                              BR_Reason 2022-05-26 01:45:35.133
# 1          dbo                           BuildVersion 2022-05-15 20:04:00.113
# 2          dbo                                   Date 2022-05-26 01:44:54.340
# 3          dbo                    DIM_Eviction_Reason 2022-05-26 01:34:00.140
# 4          dbo                               ErrorLog 2022-05-15 20:04:00.113
# 5          dbo                      FACT_SanFrancisco 2022-05-26 01:42:34.680
# 6          dbo                           Rel_Building 2022-05-17 22:49:05.513
# 7          dbo                   Rel_BuyoutAgreements 2022-05-17 22:47:28.627
# 8          dbo                       Rel_Demographics 2022-05-17 22:34:37.987
# 9          dbo                   Rel_Eviction_Notices 2022-05-17 21:59:47.223
# 10         dbo                           Rel_Location 2022-05-17 22:25:35.210
# 11         dbo            SF_Addresses_With_Units_Raw 2022-05-19 01:46:22.717
# 12         dbo               SF_Buyout_Agreements_Raw 2022-05-16 00:27:00.917
# 13         dbo                SF_Eviction_Notices_Raw 2022-05-16 00:41:20.143
# 14         dbo               Zip_Atlas_Median_Age_Raw 2022-05-16 00:26:38.500
# 15         dbo  Zip_Atlas_Median_Household_Income_Raw 2022-05-16 00:26:44.743
# 16         dbo       Zip_Atlas_Population_Density_Raw 2022-05-16 00:26:41.683
#
#                modify_date
# 0  2022-05-26 01:45:35.133
# 1  2022-05-15 20:04:01.767
# 2  2022-05-26 01:44:54.340
# 3  2022-05-26 01:45:35.137
# 4  2022-05-15 20:04:01.767
# 5  2022-05-26 01:42:34.680
# 6  2022-05-19 22:05:23.507
# 7  2022-05-26 01:39:29.083
# 8  2022-05-19 22:21:30.853
# 9  2022-05-19 23:24:13.557
# 10 2022-05-25 12:56:24.520
# 11 2022-05-19 01:46:22.793
# 12 2022-05-16 00:27:00.943
# 13 2022-05-16 00:41:20.190
# 14 2022-05-16 00:26:38.530
# 15 2022-05-16 00:26:44.773
# 16 2022-05-16 00:26:41.693

# %% [markdown]
# ### Date Table

# %%
create_Date_table_query = """
CREATE TABLE Date
(
    Date_Key                                            VARCHAR(432) PRIMARY KEY,
    Date_Type                                           VARCHAR(max) NOT NULL,
    Day_Name                                            VARCHAR(max),
    Day_Of_Week                                         INT,
    Month                                               INT,
    Month_Name                                          VARCHAR(max),
    Month_Year                                          DATE,
    Year                                                INT,
    Year_Month                                          DATE,
)
"""

# %%
## Create the table
engine = sa.create_engine(conn_string, pool_timeout=60)
connection = engine.connect()

engine.execute(create_Date_table_query)

# %%
tables = pd.read_sql_query(query, connection)
tables
# Out:
#    schema_name                             table_name             create_date  \
# 0          dbo                              BR_Reason 2022-05-26 01:35:07.260
# 1          dbo                           BuildVersion 2022-05-15 20:04:00.113
# 2          dbo                                   Date 2022-05-26 01:44:54.340
# 3          dbo                    DIM_Eviction_Reason 2022-05-26 01:34:00.140
# 4          dbo                               ErrorLog 2022-05-15 20:04:00.113
# 5          dbo                      FACT_SanFrancisco 2022-05-26 01:42:34.680
# 6          dbo                           Rel_Building 2022-05-17 22:49:05.513
# 7          dbo                   Rel_BuyoutAgreements 2022-05-17 22:47:28.627
# 8          dbo                       Rel_Demographics 2022-05-17 22:34:37.987
# 9          dbo                   Rel_Eviction_Notices 2022-05-17 21:59:47.223
# 10         dbo                           Rel_Location 2022-05-17 22:25:35.210
# 11         dbo            SF_Addresses_With_Units_Raw 2022-05-19 01:46:22.717
# 12         dbo               SF_Buyout_Agreements_Raw 2022-05-16 00:27:00.917
# 13         dbo                SF_Eviction_Notices_Raw 2022-05-16 00:41:20.143
# 14         dbo               Zip_Atlas_Median_Age_Raw 2022-05-16 00:26:38.500
# 15         dbo  Zip_Atlas_Median_Household_Income_Raw 2022-05-16 00:26:44.743
# 16         dbo       Zip_Atlas_Population_Density_Raw 2022-05-16 00:26:41.683
#
#                modify_date
# 0  2022-05-26 01:35:07.260
# 1  2022-05-15 20:04:01.767
# 2  2022-05-26 01:44:54.340
# 3  2022-05-26 01:35:07.263
# 4  2022-05-15 20:04:01.767
# 5  2022-05-26 01:42:34.680
# 6  2022-05-19 22:05:23.507
# 7  2022-05-26 01:39:29.083
# 8  2022-05-19 22:21:30.853
# 9  2022-05-19 23:24:13.557
# 10 2022-05-25 12:56:24.520
# 11 2022-05-19 01:46:22.793
# 12 2022-05-16 00:27:00.943
# 13 2022-05-16 00:41:20.190
# 14 2022-05-16 00:26:38.530
# 15 2022-05-16 00:26:44.773
# 16 2022-05-16 00:26:41.693

# %% [markdown]
# ### DIM_Demographics

# %%
create_DIM_Demographics_table_query = """
CREATE TABLE DIM_Demographics
(
    People_per_Sq_Mile                                  INT,
    Avg_Income_Per_Household                            INT,
    Population                                          INT,
    Zip_Code                                            VARCHAR(max),
    Avg_Population_Age                                  INT,
    City                                                VARCHAR(max),
    Latitude_Longitude                                  VARCHAR(max)
)
"""

# %%
## Create the table
engine = sa.create_engine(conn_string, pool_timeout=60)
connection = engine.connect()

engine.execute(create_DIM_Demographics_table_query)

# %%
tables = pd.read_sql_query(query, connection)
tables
# Out:
#    schema_name                             table_name             create_date  \
# 0          dbo                              BR_Reason 2022-05-26 01:45:35.133
# 1          dbo                           BuildVersion 2022-05-15 20:04:00.113
# 2          dbo                                   Date 2022-05-26 01:44:54.340
# 3          dbo                       DIM_Demographics 2022-05-26 01:59:27.683
# 4          dbo                           DIM_District 2022-05-26 01:55:06.617
# 5          dbo                    DIM_Eviction_Reason 2022-05-26 01:34:00.140
# 6          dbo                               ErrorLog 2022-05-15 20:04:00.113
# 7          dbo                           Rel_Building 2022-05-17 22:49:05.513
# 8          dbo                   Rel_BuyoutAgreements 2022-05-17 22:47:28.627
# 9          dbo                       Rel_Demographics 2022-05-17 22:34:37.987
# 10         dbo                   Rel_Eviction_Notices 2022-05-17 21:59:47.223
# 11         dbo                           Rel_Location 2022-05-17 22:25:35.210
# 12         dbo            SF_Addresses_With_Units_Raw 2022-05-19 01:46:22.717
# 13         dbo               SF_Buyout_Agreements_Raw 2022-05-16 00:27:00.917
# 14         dbo                SF_Eviction_Notices_Raw 2022-05-16 00:41:20.143
# 15         dbo               Zip_Atlas_Median_Age_Raw 2022-05-16 00:26:38.500
# 16         dbo  Zip_Atlas_Median_Household_Income_Raw 2022-05-16 00:26:44.743
# 17         dbo       Zip_Atlas_Population_Density_Raw 2022-05-16 00:26:41.683
#
#                modify_date
# 0  2022-05-26 01:45:35.133
# 1  2022-05-15 20:04:01.767
# 2  2022-05-26 01:44:54.340
# 3  2022-05-26 01:59:27.683
# 4  2022-05-26 01:55:06.617
# 5  2022-05-26 01:45:35.137
# 6  2022-05-15 20:04:01.767
# 7  2022-05-19 22:05:23.507
# 8  2022-05-26 01:39:29.083
# 9  2022-05-19 22:21:30.853
# 10 2022-05-19 23:24:13.557
# 11 2022-05-25 12:56:24.520
# 12 2022-05-19 01:46:22.793
# 13 2022-05-16 00:27:00.943
# 14 2022-05-16 00:41:20.190
# 15 2022-05-16 00:26:38.530
# 16 2022-05-16 00:26:44.773
# 17 2022-05-16 00:26:41.693

# %% [markdown]
# ### DIM_District

# %%
create_DIM_District_table_query = """
CREATE TABLE DIM_District
(
    Location_Key                                         VARCHAR(432) PRIMARY KEY,
    Block_Level_Address                                  VARCHAR(max),
    Zip_Code                                             INT,
    Supervisor_District                                  INT,
    City                                                 VARCHAR(max),
    State                                                VARCHAR(max),
    Location                                             VARCHAR(max),
    Shape                                                VARCHAR(max)
)
"""

# %%
## Create the table
engine = sa.create_engine(conn_string, pool_timeout=60)
connection = engine.connect()

engine.execute(create_DIM_District_table_query)

# %%
tables = pd.read_sql_query(query, connection)
tables
# Out:
#    schema_name                             table_name             create_date  \
# 0          dbo                              BR_Reason 2022-05-26 01:45:35.133
# 1          dbo                           BuildVersion 2022-05-15 20:04:00.113
# 2          dbo                                   Date 2022-05-26 01:44:54.340
# 3          dbo                           DIM_District 2022-05-26 01:55:06.617
# 4          dbo                    DIM_Eviction_Reason 2022-05-26 01:34:00.140
# 5          dbo                               ErrorLog 2022-05-15 20:04:00.113
# 6          dbo                           Rel_Building 2022-05-17 22:49:05.513
# 7          dbo                   Rel_BuyoutAgreements 2022-05-17 22:47:28.627
# 8          dbo                       Rel_Demographics 2022-05-17 22:34:37.987
# 9          dbo                   Rel_Eviction_Notices 2022-05-17 21:59:47.223
# 10         dbo                           Rel_Location 2022-05-17 22:25:35.210
# 11         dbo            SF_Addresses_With_Units_Raw 2022-05-19 01:46:22.717
# 12         dbo               SF_Buyout_Agreements_Raw 2022-05-16 00:27:00.917
# 13         dbo                SF_Eviction_Notices_Raw 2022-05-16 00:41:20.143
# 14         dbo               Zip_Atlas_Median_Age_Raw 2022-05-16 00:26:38.500
# 15         dbo  Zip_Atlas_Median_Household_Income_Raw 2022-05-16 00:26:44.743
# 16         dbo       Zip_Atlas_Population_Density_Raw 2022-05-16 00:26:41.683
#
#                modify_date
# 0  2022-05-26 01:45:35.133
# 1  2022-05-15 20:04:01.767
# 2  2022-05-26 01:44:54.340
# 3  2022-05-26 01:55:06.617
# 4  2022-05-26 01:45:35.137
# 5  2022-05-15 20:04:01.767
# 6  2022-05-19 22:05:23.507
# 7  2022-05-26 01:39:29.083
# 8  2022-05-19 22:21:30.853
# 9  2022-05-19 23:24:13.557
# 10 2022-05-25 12:56:24.520
# 11 2022-05-19 01:46:22.793
# 12 2022-05-16 00:27:00.943
# 13 2022-05-16 00:41:20.190
# 14 2022-05-16 00:26:38.530
# 15 2022-05-16 00:26:44.773
# 16 2022-05-16 00:26:41.693

# %% [markdown]
# ## Create FACT table

# %%
create_fact_table_query = """
CREATE TABLE FACT_SanFrancisco
(
    Count_BuyoutID                                       INT,
    Eviction_Key                                         VARCHAR(432),
    Location_Key                                         VARCHAR(432) FOREIGN KEY REFERENCES DIM_District(Location_Key),
    Date_Key                                             VARCHAR(432) FOREIGN KEY REFERENCES Date(Date_Key),
    Reason_GroupKey                                      VARCHAR(432) FOREIGN KEY REFERENCES BR_Reason(Reason_GroupKey),
    Count_EvictionID                                     INT,
    Count_Buyout                                         INT,
    Count_PreBuyout                                      INT
)
"""

# %%
## Create the table
engine = sa.create_engine(conn_string, pool_timeout=60)
connection = engine.connect()

engine.execute(create_fact_table_query)

# %%
tables = pd.read_sql_query(query, connection)
tables
# Out:
#    schema_name                             table_name             create_date  \
# 0          dbo                              BR_Reason 2022-05-26 01:45:35.133
# 1          dbo                           BuildVersion 2022-05-15 20:04:00.113
# 2          dbo                                   Date 2022-05-26 01:44:54.340
# 3          dbo                       DIM_Demographics 2022-05-26 01:59:27.683
# 4          dbo                           DIM_District 2022-05-26 01:55:06.617
# 5          dbo                    DIM_Eviction_Reason 2022-05-26 01:34:00.140
# 6          dbo                               ErrorLog 2022-05-15 20:04:00.113
# 7          dbo                      FACT_SanFrancisco 2022-05-26 01:59:52.130
# 8          dbo                           Rel_Building 2022-05-17 22:49:05.513
# 9          dbo                   Rel_BuyoutAgreements 2022-05-17 22:47:28.627
# 10         dbo                       Rel_Demographics 2022-05-17 22:34:37.987
# 11         dbo                   Rel_Eviction_Notices 2022-05-17 21:59:47.223
# 12         dbo                           Rel_Location 2022-05-17 22:25:35.210
# 13         dbo            SF_Addresses_With_Units_Raw 2022-05-19 01:46:22.717
# 14         dbo               SF_Buyout_Agreements_Raw 2022-05-16 00:27:00.917
# 15         dbo                SF_Eviction_Notices_Raw 2022-05-16 00:41:20.143
# 16         dbo               Zip_Atlas_Median_Age_Raw 2022-05-16 00:26:38.500
# 17         dbo  Zip_Atlas_Median_Household_Income_Raw 2022-05-16 00:26:44.743
# 18         dbo       Zip_Atlas_Population_Density_Raw 2022-05-16 00:26:41.683
#
#                modify_date
# 0  2022-05-26 01:59:52.133
# 1  2022-05-15 20:04:01.767
# 2  2022-05-26 01:59:52.133
# 3  2022-05-26 01:59:27.683
# 4  2022-05-26 01:59:52.133
# 5  2022-05-26 01:45:35.137
# 6  2022-05-15 20:04:01.767
# 7  2022-05-26 01:59:52.130
# 8  2022-05-19 22:05:23.507
# 9  2022-05-26 01:39:29.083
# 10 2022-05-19 22:21:30.853
# 11 2022-05-19 23:24:13.557
# 12 2022-05-25 12:56:24.520
# 13 2022-05-19 01:46:22.793
# 14 2022-05-16 00:27:00.943
# 15 2022-05-16 00:41:20.190
# 16 2022-05-16 00:26:38.530
# 17 2022-05-16 00:26:44.773
# 18 2022-05-16 00:26:41.693
